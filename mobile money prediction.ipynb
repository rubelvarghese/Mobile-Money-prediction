# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("all7train.csv")
test = pd.read_csv("all7test.csv")

# %%
data.isnull().sum()
# Out:
# ID                             0
# Q1                             0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q6                             0
# Q7                             0
# Q8_1                           0
# Q8_2                           0
# Q8_3                           0
# Q8_4                           0
# Q8_5                           0
# Q8_6                           0
# Q8_7                           0
# Q8_8                           0
# Q8_9                           0
# Q8_10                          0
# Q8_11                          0
# Q9                             0
# Q10                            0
# Q11                            0
# Q12                            0
# Q13                            0
# Q14                            0
# Q15                            0
# Q16                            0
# Q17                            0
# ...

# %%
data.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  borrowing  insurance  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...          0          0
# 1  1258  40   1   1   3   5   1   1     1     0  ...          1          0
# 2   331  18   2   4   6   3   2   1     0     0  ...          0          0
# 3  6729  50   1   1   3   1   1   1     0     0  ...          1          0
# 4  8671  34   1   1   1   1   2   1     0     1  ...          0          1
#
#    mobile_money_classification        district    region            ward  \
# 0                            0          Kasulu    Kigoma           Bombo
# 1                            3        Zanzibar  Zanzibar        Chiponda
# 2                            2  Morogoro Urban  Morogoro  Bupandwam'hela
# 3                            3          Karatu    Arusha     Bomba Mbili
# 4                            3          Mpanda     Rukwa          Bweleo
#
#          standalone_agent  withdrawls_airtel_cash  deposits_airtel_cash  \
# ...

# %%
data.drop(['mobile_money', 'savings', 'borrowing', 'insurance','Q8_1','Q12','Q14','Q6','Q9','Q8_7','Q8_3','Q8_8','Q8_9','Q8_5','Q8_4','Q7','Q8_11','trading_hours','withdrawls_airtel_cash','deposits_airtel_cash','standalone_agent'], axis = 1,inplace = True)

# %%
test.drop(['Q8_1','Q12','Q14','Q6','Q9','Q8_7','Q8_3','Q8_8','Q8_9','Q8_5','Q8_4','Q7','Q8_11','trading_hours','withdrawls_airtel_cash','deposits_airtel_cash','standalone_agent'], axis = 1,inplace = True)

# %%
test.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q8_2  Q8_6  Q8_10  Q10  ...  Q15  Q16  Q17  Q18  \
# 0  2352  30   2   1   3   6     0     0      0   -1  ...    4    5   -1    1
# 1  8208  53   1   1   3   1     1     0      0    1  ...    4    1   -1    1
# 2  2785  23   2   1   3   5     0     0      0   -1  ...    4    1   -1    1
# 3  2967  30   2   3   3   4     1     0      0    1  ...   -1    1   -1    1
# 4  1697  28   2   1   5   4     0     0      0   -1  ...    6    4    3    1
#
#    Q19  Latitude  Longitude      district  region      ward
# 0    4 -2.596421  32.913584      Misungwi  Mwanza     Bungu
# 1    4 -1.778303  34.062640         Bunda    Mara    Bakoba
# 2    1 -1.851789  31.536866        Muleba  Kagera   Busolwa
# 3    4 -1.235656  34.229012         Rorya    Mara  Bwongera
# 4    2 -7.780934  35.691878  Iringa Urban  Iringa   Bisheke
#
# [5 rows x 22 columns]

# %%
data.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q8_2  Q8_6  Q8_10  Q10  ...  Q16  Q17  Q18  Q19  \
# 0  5086  98   2   3   1   1     0     0      0   -1  ...    1   -1    4    4
# 1  1258  40   1   1   3   5     0     0      0   -1  ...    4    4    1    4
# 2   331  18   2   4   6   3     0     0      0   -1  ...    1   -1    1    1
# 3  6729  50   1   1   3   1     0     0      0   -1  ...    4   -1    1    4
# 4  8671  34   1   1   1   1     1     0      0    1  ...    1   -1    1    4
#
#    Latitude  Longitude  mobile_money_classification        district    region  \
# 0 -4.460442  29.811396                            0          Kasulu    Kigoma
# 1 -6.176438  39.244871                            3        Zanzibar  Zanzibar
# 2 -6.825702  37.652798                            2  Morogoro Urban  Morogoro
# 3 -3.372049  35.808307                            3          Karatu    Arusha
# 4 -7.179645  31.039095                            3          Mpanda     Rukwa
#
#              ward
# ...

# %%
ntrain = data.shape[0]
ntest = test.shape[0]

# %%
ntrain
# Out:
# 7094

# %%
all_data = pd.concat((data, test)).reset_index(drop=True)
print("all_data size is : {}".format(all_data.shape))
# Out:
# all_data size is : (9459, 23)
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
all_data.Q1.hist()

# %%
plt.scatter(x = all_data.Q1,y = all_data.mobile_money_classification)

# %%
sns.factorplot(x='Q1',y='mobile_money_classification',data=all_data,kind='bar')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
all_data.head()
# Out:
#      ID  Latitude  Longitude  Q1  Q10  Q11  Q13  Q15  Q16  Q17  ...  Q3  Q4  \
# 0  5086 -4.460442  29.811396  98   -1   -1   -1   -1    1   -1  ...   3   1
# 1  1258 -6.176438  39.244871  40   -1   -1    4    5    4    4  ...   1   3
# 2   331 -6.825702  37.652798  18   -1   -1   -1   -1    1   -1  ...   4   6
# 3  6729 -3.372049  35.808307  50   -1   -1    2   -1    4   -1  ...   1   3
# 4  8671 -7.179645  31.039095  34    1   -1   -1    1    1   -1  ...   1   1
#
#    Q5  Q8_10  Q8_2  Q8_6        district  mobile_money_classification  \
# 0   1      0     0     0          Kasulu                          0.0
# 1   5      0     0     0        Zanzibar                          3.0
# 2   3      0     0     0  Morogoro Urban                          2.0
# 3   1      0     0     0          Karatu                          3.0
# 4   1      0     1     0          Mpanda                          3.0
#
#      region            ward
# 0    Kigoma           Bombo
# 1  Zanzibar        Chiponda
# ...

# %%
cols_to_use = all_data.columns

# %%
all_data = all_data.replace(-1,0)

# %%
all_data.head()
# Out:
#      ID  Latitude  Longitude  Q1  Q10  Q11  Q13  Q15  Q16  Q17  ...  Q3  Q4  \
# 0  5086 -4.460442  29.811396  98    0    0    0    0    1    0  ...   3   1
# 1  1258 -6.176438  39.244871  40    0    0    4    5    4    4  ...   1   3
# 2   331 -6.825702  37.652798  18    0    0    0    0    1    0  ...   4   6
# 3  6729 -3.372049  35.808307  50    0    0    2    0    4    0  ...   1   3
# 4  8671 -7.179645  31.039095  34    1    0    0    1    1    0  ...   1   1
#
#    Q5  Q8_10  Q8_2  Q8_6        district  mobile_money_classification  \
# 0   1      0     0     0          Kasulu                          0.0
# 1   5      0     0     0        Zanzibar                          3.0
# 2   3      0     0     0  Morogoro Urban                          2.0
# 3   1      0     0     0          Karatu                          3.0
# 4   1      0     1     0          Mpanda                          3.0
#
#      region            ward
# 0    Kigoma           Bombo
# 1  Zanzibar        Chiponda
# ...

# %%
all_data.isnull().sum()
# Out:
# ID                                0
# Latitude                          0
# Longitude                         0
# Q1                                0
# Q10                               0
# Q11                               0
# Q13                               0
# Q15                               0
# Q16                               0
# Q17                               0
# Q18                               0
# Q19                               0
# Q2                                0
# Q3                                0
# Q4                                0
# Q5                                0
# Q8_10                             0
# Q8_2                              0
# Q8_6                              0
# district                          0
# mobile_money_classification    2365
# region                            0
# ward                              0
# dtype: int64

# %%
all_data.drop(['ID','Latitude','Longitude'],axis=1,inplace= True)

# %%
all_data.head()
# Out:
#    Q1  Q10  Q11  Q13  Q15  Q16  Q17  Q18  Q19  Q2  Q3  Q4  Q5  Q8_10  Q8_2  \
# 0  98    0    0    0    0    1    0    4    4   2   3   1   1      0     0
# 1  40    0    0    4    5    4    4    1    4   1   1   3   5      0     0
# 2  18    0    0    0    0    1    0    1    1   2   4   6   3      0     0
# 3  50    0    0    2    0    4    0    1    4   1   1   3   1      0     0
# 4  34    1    0    0    1    1    0    1    4   1   1   1   1      0     1
#
#    Q8_6        district  mobile_money_classification    region            ward
# 0     0          Kasulu                          0.0    Kigoma           Bombo
# 1     0        Zanzibar                          3.0  Zanzibar        Chiponda
# 2     0  Morogoro Urban                          2.0  Morogoro  Bupandwam'hela
# 3     0          Karatu                          3.0    Arusha     Bomba Mbili
# 4     0          Mpanda                          3.0     Rukwa          Bweleo

# %%
all_data.isnull().sum()
# Out:
# Q1                                0
# Q10                               0
# Q11                               0
# Q13                               0
# Q15                               0
# Q16                               0
# Q17                               0
# Q18                               0
# Q19                               0
# Q2                                0
# Q3                                0
# Q4                                0
# Q5                                0
# Q8_10                             0
# Q8_2                              0
# Q8_6                              0
# district                          0
# mobile_money_classification    2365
# region                            0
# ward                              0
# dtype: int64

# %%
data = data.replace(-1,0)

# %%
data.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q8_2  Q8_6  Q8_10  Q10  ...  Q16  Q17  Q18  Q19  \
# 0  5086  98   2   3   1   1     0     0      0    0  ...    1    0    4    4
# 1  1258  40   1   1   3   5     0     0      0    0  ...    4    4    1    4
# 2   331  18   2   4   6   3     0     0      0    0  ...    1    0    1    1
# 3  6729  50   1   1   3   1     0     0      0    0  ...    4    0    1    4
# 4  8671  34   1   1   1   1     1     0      0    1  ...    1    0    1    4
#
#    Latitude  Longitude  mobile_money_classification        district    region  \
# 0 -4.460442  29.811396                            0          Kasulu    Kigoma
# 1 -6.176438  39.244871                            3        Zanzibar  Zanzibar
# 2 -6.825702  37.652798                            2  Morogoro Urban  Morogoro
# 3 -3.372049  35.808307                            3          Karatu    Arusha
# 4 -7.179645  31.039095                            3          Mpanda     Rukwa
#
#              ward
# ...

# %%
all_data.head()
# Out:
#    Q1  Q10  Q11  Q13  Q15  Q16  Q17  Q18  Q19  Q2  Q3  Q4  Q5  Q8_10  Q8_2  \
# 0  98    0    0    0    0    1    0    4    4   2   3   1   1      0     0
# 1  40    0    0    4    5    4    4    1    4   1   1   3   5      0     0
# 2  18    0    0    0    0    1    0    1    1   2   4   6   3      0     0
# 3  50    0    0    2    0    4    0    1    4   1   1   3   1      0     0
# 4  34    1    0    0    1    1    0    1    4   1   1   1   1      0     1
#
#    Q8_6        district  mobile_money_classification    region            ward
# 0     0          Kasulu                          0.0    Kigoma           Bombo
# 1     0        Zanzibar                          3.0  Zanzibar        Chiponda
# 2     0  Morogoro Urban                          2.0  Morogoro  Bupandwam'hela
# 3     0          Karatu                          3.0    Arusha     Bomba Mbili
# 4     0          Mpanda                          3.0     Rukwa          Bweleo

# %%
all_data['district'] = all_data['district'].astype('category')
all_data['region'] = all_data['region'].astype('category')
all_data['ward'] = all_data['ward'].astype('category')
#all_data['standalone_agent'] = all_data['standalone_agent'].astype('category')
#all_data['trading_hours'] = all_data['trading_hours'].astype('category')

# %%
cat_columns = all_data.select_dtypes(['category']).columns

cat_columns
all_data[cat_columns] = all_data[cat_columns].apply(lambda x: x.cat.codes)
all_data.head()
# Out:
#    Q1  Q10  Q11  Q13  Q15  Q16  Q17  Q18  Q19  Q2  Q3  Q4  Q5  Q8_10  Q8_2  \
# 0  98    0    0    0    0    1    0    4    4   2   3   1   1      0     0
# 1  40    0    0    4    5    4    4    1    4   1   1   3   5      0     0
# 2  18    0    0    0    0    1    0    1    1   2   4   6   3      0     0
# 3  50    0    0    2    0    4    0    1    4   1   1   3   1      0     0
# 4  34    1    0    0    1    1    0    1    4   1   1   1   1      0     1
#
#    Q8_6  district  mobile_money_classification  region  ward
# 0     0        28                          0.0       5    28
# 1     0       120                          3.0      21   119
# 2     0        69                          2.0      11    69
# 3     0        27                          3.0       0    27
# 4     0        72                          3.0      15    89

# %%
all_data.head()
# Out:
#    Q1  Q10  Q11  Q13  Q15  Q16  Q17  Q18  Q19  Q2  Q3  Q4  Q5  Q8_10  Q8_2  \
# 0  98    0    0    0    0    1    0    4    4   2   3   1   1      0     0
# 1  40    0    0    4    5    4    4    1    4   1   1   3   5      0     0
# 2  18    0    0    0    0    1    0    1    1   2   4   6   3      0     0
# 3  50    0    0    2    0    4    0    1    4   1   1   3   1      0     0
# 4  34    1    0    0    1    1    0    1    4   1   1   1   1      0     1
#
#    Q8_6  district  mobile_money_classification  region  ward
# 0     0        28                          0.0       5    28
# 1     0       120                          3.0      21   119
# 2     0        69                          2.0      11    69
# 3     0        27                          3.0       0    27
# 4     0        72                          3.0      15    89

# %%
data = all_data[:ntrain]
test = all_data[ntrain:]

# %%
data.isnull().sum()
# Out:
# Q1                             0
# Q10                            0
# Q11                            0
# Q13                            0
# Q15                            0
# Q16                            0
# Q17                            0
# Q18                            0
# Q19                            0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q8_10                          0
# Q8_2                           0
# Q8_6                           0
# district                       0
# mobile_money_classification    0
# region                         0
# ward                           0
# dtype: int64

# %%
test.drop("mobile_money_classification",axis = 1,inplace = True)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
from sklearn.linear_model import LogisticRegression

from xgboost import XGBClassifier

# %%
X= data.drop( 'mobile_money_classification', axis = 1)
y = data["mobile_money_classification"]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y_train.head()
# Out:
# 3849    3.0
# 307     1.0
# 1278    3.0
# 3142    1.0
# 4706    3.0
# Name: mobile_money_classification, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier 
import xgboost as xgb

# %%
model = XGBClassifier(
          n_estimators= 265)

# %%
from sklearn.metrics import log_loss

# %%
X_train.head()
# Out:
#       Q1  Q10  Q11  Q13  Q15  Q16  Q17  Q18  Q19  Q2  Q3  Q4  Q5  Q8_10  Q8_2  \
# 3849  16    0    7    3    2    4    4    1    1   2   1   5   3      0     0
# 307   42    8    0    3    0    1    0    4    4   2   3   1   3      0     1
# 1278  43    1    0    4    2    4    3    1    1   2   1   3   1      0     1
# 3142  45    3    0    0    0    1    0    4    4   2   3   1   1      0     1
# 4706  20    0    0    3    2    5    0    1    4   2   1   3   4      1     0
#
#       Q8_6  district  region  ward
# 3849     0        65      13    65
# 307      0        99      13    98
# 1278     0        76       3    88
# 3142     0        42      18    55
# 4706     0        90      13    90

# %%
y_train.head()
# Out:
# 3849    3.0
# 307     1.0
# 1278    3.0
# 3142    1.0
# 4706    3.0
# Name: mobile_money_classification, dtype: float64

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=265, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
pred = model.predict_proba(X_test)
pred
# Out:
# array([[5.9634018e-01, 3.2326183e-01, 3.5569299e-02, 4.4828724e-02],
#        [2.9405221e-01, 6.4114851e-01, 2.5370564e-02, 3.9428711e-02],
#        [1.1128683e-03, 9.6123768e-03, 2.8741616e-01, 7.0185858e-01],
#        ...,
#        [1.3540918e-03, 1.8805494e-03, 7.9639211e-02, 9.1712612e-01],
#        [5.6056954e-02, 1.2640156e-01, 1.2782490e-01, 6.8971658e-01],
#        [1.6512816e-04, 6.5085585e-03, 2.7527183e-02, 9.6579915e-01]],
#       dtype=float32)

# %%
log_loss(y_test,pred)
# Out:
# 0.7803266999515048

# %%
import matplotlib.pyplot as plt
xgb.plot_importance(model,max_num_features=34)
plt.rcParams['figure.figsize'] = [15, 5]

# %%
X_test.head()
# Out:
#       Q1  Q10  Q11  Q13  Q15  Q16  Q17  Q18  Q19  Q2  Q3  Q4  Q5  Q8_10  Q8_2  \
# 7057  16    0    0    0    0    1    0    1    4   2   4   5   3      0     0
# 5724  75    1    0    0    0    1    0    1    4   1   1   2   1      0     1
# 2887  41    1    0    3    4    1    0    1    4   1   1   3   4      0     1
# 3846  26    1    0    0    4    1    0    1    1   1   1   3   4      0     1
# 1172  40    0    0    0    0    1    0    4    4   1   1   2   1      0     0
#
#       Q8_6  district  region  ward
# 7057     0       100       9     4
# 5724     0        67       0    67
# 2887     0        62      10    62
# 3846     0        56      12    56
# 1172     0       120      21   119

# %%
a=model.predict(X_test)

# %%
a
# Out:
# array([0., 1., 3., ..., 3., 3., 3.])

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
results = confusion_matrix(y_test, a)

# %%
print('Confusion Matrix :')
print(results) 
print('Accuracy Score :',accuracy_score(y_test, a)) 
print('Report : ')
print(classification_report(y_test, a))
# Out:
# Confusion Matrix :
# [[174 245   3  12]
#  [134 379   4  37]
#  [ 10  16  20 156]
#  [ 15  54  32 838]]
# Accuracy Score : 0.6627524659464538
# Report :
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.40      0.45       434
#          1.0       0.55      0.68      0.61       554
#          2.0       0.34      0.10      0.15       202
#          3.0       0.80      0.89      0.85       939
#
#     accuracy                           0.66      2129
#    macro avg       0.55      0.52      0.51      2129
# weighted avg       0.64      0.66      0.64      2129

# %%
accuracy_score(y_test, a)
# Out:
# 0.6627524659464538

# %%
sample = pd.read_csv("sample_submission.csv")
sample.head()
# Out:
#      ID  no_financial_services  other_only  mm_only  mm_plus
# 0  2352                 0.5423      0.9987     0.12   0.0123
# 1  8208                    NaN         NaN      NaN      NaN
# 2  2785                    NaN         NaN      NaN      NaN
# 3  2967                    NaN         NaN      NaN      NaN
# 4  1697                    NaN         NaN      NaN      NaN

# %%
pred = pd.DataFrame(model.predict_proba(X_test),columns= [ 'no_financial_services', 'other_only', 'mm_only', 'mm_plus'])

# %%
pred = pd.concat([sample["ID"], pred], axis =1)

# %%
pred.head()
# Out:
#      ID  no_financial_services  other_only   mm_only   mm_plus
# 0  2352               0.596340    0.323262  0.035569  0.044829
# 1  8208               0.294052    0.641149  0.025371  0.039429
# 2  2785               0.001113    0.009612  0.287416  0.701859
# 3  2967               0.017061    0.031354  0.186977  0.764608
# 4  1697               0.466491    0.502829  0.012972  0.017709

# %%
import pickle

# %%
saved_modell=open("saved_modell.dat","wb")

# %%
pickle.dump(model,saved_modell)

# %%
saved_modell.close()
